# %% [markdown]
# Connected to Python 3.9.6

# %%
import serial.tools.list_ports as port_list
ports = list(port_list.comports())
for p in ports:
    print (p)

# ---------------------------------------------------------------------------------------

# import serial
# import time

# serialPort = serial.Serial(
#     port="COM4", baudrate=9600, bytesize=8, timeout=2, stopbits=serial.STOPBITS_ONE
# )
# serialString = ""  # Used to hold data coming over UART
# while 1:
#     # Read data out of the buffer until a carraige return / new line is found
#     serialString = serialPort.readline()

#     # Print the contents of the serial data
#     try:
#         print(serialString.decode("Ascii"))
#     except:
#         pass

# ---------------------------------------------------------------------------------------

# # Python code transmits a byte to Arduino /Microcontroller
# import time
# import serial

# import serial.tools.list_ports
# ports = serial.tools.list_ports.comports()

# for port, desc, hwid in sorted(ports):
#         print("{}: {} [{}]".format(port, desc, hwid))
# # /Get avail ports then select port


# SerialObj = serial.Serial('COM18')  # COMxx  format on Windows
#                                     # ttyUSBx format on Linux
# SerialObj.baudrate = 9600           # set Baud rate to 9600
# SerialObj.bytesize = 8              # Number of data bits = 8
# SerialObj.parity  ='N'              # No parity
# SerialObj.stopbits = 1              # Number of Stop bits = 1
# time.sleep(3)
# while True:
#     SerialObj.write(b"asdfghjkl")
#     break
# SerialObj.close()
# #     time.sleep(1)
# # SerialObj.close()      # Close the port
# Out:
# /dev/cu.MoondropSpaceTravel - n/a
# /dev/cu.Bluetooth-Incoming-Port - n/a

# %%
import serial.tools.list_ports as port_list
ports = list(port_list.comports())
for p in ports:
    print (p)

# ---------------------------------------------------------------------------------------

# import serial
# import time

# serialPort = serial.Serial(
#     port="COM4", baudrate=9600, bytesize=8, timeout=2, stopbits=serial.STOPBITS_ONE
# )
# serialString = ""  # Used to hold data coming over UART
# while 1:
#     # Read data out of the buffer until a carraige return / new line is found
#     serialString = serialPort.readline()

#     # Print the contents of the serial data
#     try:
#         print(serialString.decode("Ascii"))
#     except:
#         pass

# ---------------------------------------------------------------------------------------

# # Python code transmits a byte to Arduino /Microcontroller
# import time
# import serial

# import serial.tools.list_ports
# ports = serial.tools.list_ports.comports()

# for port, desc, hwid in sorted(ports):
#         print("{}: {} [{}]".format(port, desc, hwid))
# # /Get avail ports then select port


# SerialObj = serial.Serial('/dev/cu.Bluetooth-Incoming-Port')  # COMxx  format on Windows
#                                     # ttyUSBx format on Linux
# SerialObj.baudrate = 9600           # set Baud rate to 9600
# SerialObj.bytesize = 8              # Number of data bits = 8
# SerialObj.parity  ='N'              # No parity
# SerialObj.stopbits = 1              # Number of Stop bits = 1
# time.sleep(3)
# while True:
#     SerialObj.write(b"asdfghjkl")
#     break
# SerialObj.close()
# #     time.sleep(1)
# # SerialObj.close()      # Close the port
# Out:
# /dev/cu.MoondropSpaceTravel - n/a
# /dev/cu.Bluetooth-Incoming-Port - n/a
# /dev/cu.usbmodem101 - Arduino Uno

# %%
import serial.tools.list_ports as port_list
ports = list(port_list.comports())
for p in ports:
    print (p)

# ---------------------------------------------------------------------------------------

# import serial
# import time

# serialPort = serial.Serial(
#     port="COM4", baudrate=9600, bytesize=8, timeout=2, stopbits=serial.STOPBITS_ONE
# )
# serialString = ""  # Used to hold data coming over UART
# while 1:
#     # Read data out of the buffer until a carraige return / new line is found
#     serialString = serialPort.readline()

#     # Print the contents of the serial data
#     try:
#         print(serialString.decode("Ascii"))
#     except:
#         pass

# ---------------------------------------------------------------------------------------

# Python code transmits a byte to Arduino /Microcontroller
import time
import serial

import serial.tools.list_ports
ports = serial.tools.list_ports.comports()

for port, desc, hwid in sorted(ports):
        print("{}: {} [{}]".format(port, desc, hwid))
# /Get avail ports then select port


SerialObj = serial.Serial('/dev/cu.usbmodem101')
                                    # ttyUSBx format on Linux
SerialObj.baudrate = 9600           # set Baud rate to 9600
SerialObj.bytesize = 8              # Number of data bits = 8
SerialObj.parity  ='N'              # No parity
SerialObj.stopbits = 1              # Number of Stop bits = 1
time.sleep(3)
while True:
    SerialObj.write(b"asdfghjkl")
    break
SerialObj.close()
#     time.sleep(1)
# SerialObj.close()      # Close the port
# Out:
# /dev/cu.MoondropSpaceTravel - n/a
# /dev/cu.Bluetooth-Incoming-Port - n/a
# /dev/cu.usbmodem101 - Arduino Uno
# /dev/cu.Bluetooth-Incoming-Port: n/a [n/a]
# /dev/cu.MoondropSpaceTravel: n/a [n/a]
# /dev/cu.usbmodem101: Arduino Uno [USB VID:PID=2341:0043 SER=12154501101137905650 LOCATION=0-1]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/serial/serialposix.py:322, in Serial.open(self)
#     321 try:
# --> 322     self.fd = os.open(self.portstr, os.O_RDWR | os.O_NOCTTY | os.O_NONBLOCK)
#     323 except OSError as msg:
#
# OSError: [Errno 16] Resource busy: '/dev/cu.usbmodem101'
#
# During handling of the above exception, another exception occurred:
#
# SerialException                           Traceback (most recent call last)
# File /Users/lionelliu/Documents/STEI-R Sem 3/EL2002/TUBES-PYTHON/uart_tx.py:39
#      35         print("{}: {} [{}]".format(port, desc, hwid))
#      36 # /Get avail ports then select port
# ---> 39 SerialObj = serial.Serial('/dev/cu.usbmodem101')
#      40                                     # ttyUSBx format on Linux
#      41 SerialObj.baudrate = 9600           # set Baud rate to 9600
#
# File ~/Library/Python/3.9/lib/python/site-packages/serial/serialutil.py:244, in SerialBase.__init__(self, port, baudrate, bytesize, parity, stopbits, timeout, xonxoff, rtscts, write_timeout, dsrdtr, inter_byte_timeout, exclusive, **kwargs)
#     241     raise ValueError('unexpected keyword arguments: {!r}'.format(kwargs))
#     243 if port is not None:
# --> 244     self.open()
#
# File ~/Library/Python/3.9/lib/python/site-packages/serial/serialposix.py:325, in Serial.open(self)
#     323 except OSError as msg:
#     324     self.fd = None
# --> 325     raise SerialException(msg.errno, "could not open port {}: {}".format(self._port, msg))
#     326 #~ fcntl.fcntl(self.fd, fcntl.F_SETFL, 0)  # set blocking
#     328 self.pipe_abort_read_r, self.pipe_abort_read_w = None, None
#
# SerialException: [Errno 16] could not open port /dev/cu.usbmodem101: [Errno 16] Resource busy: '/dev/cu.usbmodem101'

# %%
# import serial.tools.list_ports as port_list
# ports = list(port_list.comports())
# for p in ports:
#     print (p)

# ---------------------------------------------------------------------------------------

# import serial
# import time

# serialPort = serial.Serial(
#     port="COM4", baudrate=9600, bytesize=8, timeout=2, stopbits=serial.STOPBITS_ONE
# )
# serialString = ""  # Used to hold data coming over UART
# while 1:
#     # Read data out of the buffer until a carraige return / new line is found
#     serialString = serialPort.readline()

#     # Print the contents of the serial data
#     try:
#         print(serialString.decode("Ascii"))
#     except:
#         pass

# ---------------------------------------------------------------------------------------

# Python code transmits a byte to Arduino /Microcontroller
import time
import serial

import serial.tools.list_ports
ports = serial.tools.list_ports.comports()

for port, desc, hwid in sorted(ports):
        print("{}: {} [{}]".format(port, desc, hwid))
# /Get avail ports then select port


SerialObj = serial.Serial('/dev/cu.usbmodem101')
                                    # ttyUSBx format on Linux
SerialObj.baudrate = 9600           # set Baud rate to 9600
SerialObj.bytesize = 8              # Number of data bits = 8
SerialObj.parity  ='N'              # No parity
SerialObj.stopbits = 1              # Number of Stop bits = 1
time.sleep(3)
while True:
    SerialObj.write(b"1")
    break
SerialObj.close()
#     time.sleep(1)
# SerialObj.close()      # Close the port
# Out:
# /dev/cu.Bluetooth-Incoming-Port: n/a [n/a]
# /dev/cu.MoondropSpaceTravel: n/a [n/a]
# /dev/cu.usbmodem101: Arduino Uno [USB VID:PID=2341:0043 SER=12154501101137905650 LOCATION=0-1]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/serial/serialposix.py:322, in Serial.open(self)
#     321 try:
# --> 322     self.fd = os.open(self.portstr, os.O_RDWR | os.O_NOCTTY | os.O_NONBLOCK)
#     323 except OSError as msg:
#
# OSError: [Errno 16] Resource busy: '/dev/cu.usbmodem101'
#
# During handling of the above exception, another exception occurred:
#
# SerialException                           Traceback (most recent call last)
# File /Users/lionelliu/Documents/STEI-R Sem 3/EL2002/TUBES-PYTHON/uart_tx.py:39
#      35         print("{}: {} [{}]".format(port, desc, hwid))
#      36 # /Get avail ports then select port
# ---> 39 SerialObj = serial.Serial('/dev/cu.usbmodem101')
#      40                                     # ttyUSBx format on Linux
#      41 SerialObj.baudrate = 9600           # set Baud rate to 9600
#
# File ~/Library/Python/3.9/lib/python/site-packages/serial/serialutil.py:244, in SerialBase.__init__(self, port, baudrate, bytesize, parity, stopbits, timeout, xonxoff, rtscts, write_timeout, dsrdtr, inter_byte_timeout, exclusive, **kwargs)
#     241     raise ValueError('unexpected keyword arguments: {!r}'.format(kwargs))
#     243 if port is not None:
# --> 244     self.open()
#
# File ~/Library/Python/3.9/lib/python/site-packages/serial/serialposix.py:325, in Serial.open(self)
#     323 except OSError as msg:
#     324     self.fd = None
# --> 325     raise SerialException(msg.errno, "could not open port {}: {}".format(self._port, msg))
#     326 #~ fcntl.fcntl(self.fd, fcntl.F_SETFL, 0)  # set blocking
#     328 self.pipe_abort_read_r, self.pipe_abort_read_w = None, None
#
# SerialException: [Errno 16] could not open port /dev/cu.usbmodem101: [Errno 16] Resource busy: '/dev/cu.usbmodem101'

# %%
# import serial.tools.list_ports as port_list
# ports = list(port_list.comports())
# for p in ports:
#     print (p)

# ---------------------------------------------------------------------------------------

# import serial
# import time

# serialPort = serial.Serial(
#     port="COM4", baudrate=9600, bytesize=8, timeout=2, stopbits=serial.STOPBITS_ONE
# )
# serialString = ""  # Used to hold data coming over UART
# while 1:
#     # Read data out of the buffer until a carraige return / new line is found
#     serialString = serialPort.readline()

#     # Print the contents of the serial data
#     try:
#         print(serialString.decode("Ascii"))
#     except:
#         pass

# ---------------------------------------------------------------------------------------

# Python code transmits a byte to Arduino /Microcontroller
import time
import serial

import serial.tools.list_ports
ports = serial.tools.list_ports.comports()

for port, desc, hwid in sorted(ports):
        print("{}: {} [{}]".format(port, desc, hwid))
# /Get avail ports then select port


SerialObj = serial.Serial('/dev/cu.usbmodem101')
                                    # ttyUSBx format on Linux
SerialObj.baudrate = 9600           # set Baud rate to 9600
SerialObj.bytesize = 8              # Number of data bits = 8
SerialObj.parity  ='N'              # No parity
SerialObj.stopbits = 1              # Number of Stop bits = 1
time.sleep(3)
while True:
    SerialObj.write(b"1")
    break
SerialObj.close()
#     time.sleep(1)
# SerialObj.close()      # Close the port
# Out:
# /dev/cu.Bluetooth-Incoming-Port: n/a [n/a]
# /dev/cu.MoondropSpaceTravel: n/a [n/a]
# /dev/cu.usbmodem101: Arduino Uno [USB VID:PID=2341:0043 SER=12154501101137905650 LOCATION=0-1]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/serial/serialposix.py:322, in Serial.open(self)
#     321 try:
# --> 322     self.fd = os.open(self.portstr, os.O_RDWR | os.O_NOCTTY | os.O_NONBLOCK)
#     323 except OSError as msg:
#
# OSError: [Errno 16] Resource busy: '/dev/cu.usbmodem101'
#
# During handling of the above exception, another exception occurred:
#
# SerialException                           Traceback (most recent call last)
# File /Users/lionelliu/Documents/STEI-R Sem 3/EL2002/TUBES-PYTHON/uart_tx.py:39
#      35         print("{}: {} [{}]".format(port, desc, hwid))
#      36 # /Get avail ports then select port
# ---> 39 SerialObj = serial.Serial('/dev/cu.usbmodem101')
#      40                                     # ttyUSBx format on Linux
#      41 SerialObj.baudrate = 9600           # set Baud rate to 9600
#
# File ~/Library/Python/3.9/lib/python/site-packages/serial/serialutil.py:244, in SerialBase.__init__(self, port, baudrate, bytesize, parity, stopbits, timeout, xonxoff, rtscts, write_timeout, dsrdtr, inter_byte_timeout, exclusive, **kwargs)
#     241     raise ValueError('unexpected keyword arguments: {!r}'.format(kwargs))
#     243 if port is not None:
# --> 244     self.open()
#
# File ~/Library/Python/3.9/lib/python/site-packages/serial/serialposix.py:325, in Serial.open(self)
#     323 except OSError as msg:
#     324     self.fd = None
# --> 325     raise SerialException(msg.errno, "could not open port {}: {}".format(self._port, msg))
#     326 #~ fcntl.fcntl(self.fd, fcntl.F_SETFL, 0)  # set blocking
#     328 self.pipe_abort_read_r, self.pipe_abort_read_w = None, None
#
# SerialException: [Errno 16] could not open port /dev/cu.usbmodem101: [Errno 16] Resource busy: '/dev/cu.usbmodem101'

# %%
# import serial.tools.list_ports as port_list
# ports = list(port_list.comports())
# for p in ports:
#     print (p)

# ---------------------------------------------------------------------------------------

# import serial
# import time

# serialPort = serial.Serial(
#     port="COM4", baudrate=9600, bytesize=8, timeout=2, stopbits=serial.STOPBITS_ONE
# )
# serialString = ""  # Used to hold data coming over UART
# while 1:
#     # Read data out of the buffer until a carraige return / new line is found
#     serialString = serialPort.readline()

#     # Print the contents of the serial data
#     try:
#         print(serialString.decode("Ascii"))
#     except:
#         pass

# ---------------------------------------------------------------------------------------

# Python code transmits a byte to Arduino /Microcontroller
import time
import serial

import serial.tools.list_ports
ports = serial.tools.list_ports.comports()

for port, desc, hwid in sorted(ports):
        print("{}: {} [{}]".format(port, desc, hwid))
# /Get avail ports then select port


SerialObj = serial.Serial('/dev/cu.usbmodem101')
                                    # ttyUSBx format on Linux
SerialObj.baudrate = 9600           # set Baud rate to 9600
SerialObj.bytesize = 8              # Number of data bits = 8
SerialObj.parity  ='N'              # No parity
SerialObj.stopbits = 1              # Number of Stop bits = 1
time.sleep(3)
while True:
    SerialObj.write(b"1")
    break
SerialObj.close()
#     time.sleep(1)
# SerialObj.close()      # Close the port
# Out:
# /dev/cu.Bluetooth-Incoming-Port: n/a [n/a]
# /dev/cu.MoondropSpaceTravel: n/a [n/a]
# /dev/cu.usbmodem101: Arduino Uno [USB VID:PID=2341:0043 SER=12154501101137905650 LOCATION=0-1]
